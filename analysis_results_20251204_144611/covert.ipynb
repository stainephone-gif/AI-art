# %%
import pandas as pd

df = pd.read_csv('classified_data.csv', sep=',', encoding='UTF8')
df.head()
# Out:
#                  __source                     descr_author descr_author_en  \
# 0  explication_table.xlsx                    Лара Федотова             NaN
# 1  explication_table.xlsx                     volv_victory             NaN
# 2  explication_table.xlsx                       Юлия Назар             NaN
# 3  explication_table.xlsx  Жиганов Александр (студия SHUM)             NaN
# 4  explication_table.xlsx                 Лянгузов Алексей             NaN
#
#                                            title title_en  \
# 0         Sublime landscapes/Гибридные ландшафты      NaN
# 1                            All in all. Project      NaN
# 2  Клеопатра. Перевод стихотворения А.С. Пушкина      NaN
# 3                                       Киригами      NaN
# 4                                  Чувства машин      NaN
#
#                                                descr descr_en  \
# 0  Проект о гибридности современных ландшафтов со...      NaN
# ...

# %%
df.to_excel('classified_data.xlsx', index=False)
